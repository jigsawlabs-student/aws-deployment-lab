# %%
from sodapy import Socrata

# %%
client = Socrata("data.cityofnewyork.us", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("erm2-nwe9", limit=2000)

# %%
import requests
url = "https://data.cityofnewyork.us/resource/erm2-nwe9.json"
response = requests.get(url, params = {'incident_zip': 10038})
response.json()

# %%
# Out:
# [{'unique_key': '47786249',
#   'created_date': '2020-10-04T16:39:00.000',
#   'closed_date': '2020-10-05T12:00:00.000',
#   'agency': 'DSNY',
#   'agency_name': 'Manhattan 03',
#   'complaint_type': 'Derelict Vehicles',
#   'descriptor': '14 Derelict Vehicles',
#   'location_type': 'Street',
#   'incident_zip': '10038',
#   'incident_address': '51 CATHERINE STREET',
#   'street_name': 'CATHERINE STREET',
#   'cross_street_1': 'MADISON STREET',
#   'cross_street_2': 'MONROE STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'DSNY Garage',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Sanitation found an open service request already exists for the same location.',
#   'resolution_action_updated_date': '2020-10-05T03:05:00.000',
#   'community_board': '03 MANHATTAN',
#   'bbl': '1002760056',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '985127',
#   'y_coordinate_state_plane': '198545',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.71163686620811',
#   'longitude': '-73.99683658941078',
#   'location': {'latitude': '40.71163686620811',
#    'longitude': '-73.99683658941078',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '42053803',
#   'created_date': '2019-03-26T16:46:16.000',
#   'closed_date': '2019-03-27T12:27:39.000',
#   'agency': 'DOF',
#   'agency_name': 'Commercial Exemption Unit',
#   'complaint_type': 'DOF Property - Reduction Issue',
#   'descriptor': 'Commercial 421G Exemption',
#   'location_type': 'Condo Unit',
#   'incident_zip': '10038',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'due_date': '2019-04-10T09:43:26.000',
#   'resolution_description': 'See notes.',
#   'resolution_action_updated_date': '2019-03-27T12:27:39.000',
#   'community_board': '01 MANHATTAN',
#   'borough': 'MANHATTAN',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN'},
#  {'unique_key': '47788153',
#   'created_date': '2020-10-16T11:17:11.000',
#   'closed_date': '2020-10-16T11:17:12.000',
#   'agency': 'DPR',
#   'agency_name': 'Department of Parks and Recreation',
#   'complaint_type': 'Maintenance or Facility',
#   'descriptor': 'Rodent Sighting',
#   'location_type': 'Park',
#   'incident_zip': '10038',
#   'incident_address': '100 GOLD STREET',
#   'street_name': 'GOLD STREET',
#   'cross_street_1': 'SPRUCE STREET',
#   'cross_street_2': 'FRANKFORT STREET',
#   'intersection_street_1': 'SPRUCE STREET',
#   'intersection_street_2': 'FRANKFORT STREET',
#   'city': 'NEW YORK',
#   'landmark': 'GOLD STREET',
#   'status': 'Closed',
#   'resolution_description': 'The Service Request submitted did not have sufficient location or complaint information for the agency to respond.',
#   'resolution_action_updated_date': '2020-10-16T15:17:28.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000940025',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983139',
#   'y_coordinate_state_plane': '198077',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': '100 Gold St.',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.71035229111428',
#   'longitude': '-74.00400739046181',
#   'location': {'latitude': '40.71035229111428',
#    'longitude': '-74.00400739046181',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46559093',
#   'created_date': '2020-06-19T19:53:00.000',
#   'closed_date': '2020-07-20T12:00:00.000',
#   'agency': 'DSNY',
#   'agency_name': 'A - Manhattan',
#   'complaint_type': 'Dirty Conditions',
#   'descriptor': 'E3 Dirty Sidewalk',
#   'location_type': 'Sidewalk',
#   'incident_zip': '10038',
#   'incident_address': '22 DOVER STREET',
#   'street_name': 'DOVER STREET',
#   'cross_street_1': 'WATER STREET',
#   'cross_street_2': 'FRONT STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Sanitation investigated this complaint and found no violation at the location.',
#   'resolution_action_updated_date': '2020-07-20T12:00:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1001070028',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '984067',
#   'y_coordinate_state_plane': '197418',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7085435',
#   'longitude': '-74.0006601',
#   'location': {'latitude': '40.7085435',
#    'longitude': '-74.0006601',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '47397822',
#   'created_date': '2020-08-28T23:13:00.000',
#   'closed_date': '2020-09-10T12:00:00.000',
#   'agency': 'DSNY',
#   'agency_name': 'A - Manhattan',
#   'complaint_type': 'Dirty Conditions',
#   'descriptor': 'E1 Improper Disposal',
#   'location_type': 'Sidewalk',
#   'incident_zip': '10038',
#   'incident_address': '49 ANN STREET',
#   'street_name': 'ANN STREET',
#   'cross_street_1': 'NASSAU STREET',
#   'cross_street_2': 'WILLIAM STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Sanitation investigated this complaint and found no violation at the location.',
#   'resolution_action_updated_date': '2020-09-10T12:00:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000920014',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982357',
#   'y_coordinate_state_plane': '198060',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.710305497398174',
#   'longitude': '-74.00682806914837',
#   'location': {'latitude': '40.710305497398174',
#    'longitude': '-74.00682806914837',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '47410769',
#   'created_date': '2020-08-29T14:06:00.000',
#   'closed_date': '2020-09-10T12:00:00.000',
#   'agency': 'DSNY',
#   'agency_name': 'A - Manhattan',
#   'complaint_type': 'Dirty Conditions',
#   'descriptor': 'E3 Dirty Sidewalk',
#   'location_type': 'Sidewalk',
#   'incident_zip': '10038',
#   'incident_address': '10 PLATT STREET',
#   'street_name': 'PLATT STREET',
#   'cross_street_1': 'GOLD STREET',
#   'cross_street_2': 'PEARL STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Sanitation investigated this complaint and found no violation at the location.',
#   'resolution_action_updated_date': '2020-09-10T12:00:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000690030',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982465',
#   'y_coordinate_state_plane': '197056',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.70754977764916',
#   'longitude': '-74.00643824594496',
#   'location': {'latitude': '40.70754977764916',
#    'longitude': '-74.00643824594496',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46597789',
#   'created_date': '2020-06-23T17:57:35.000',
#   'closed_date': '2020-06-29T00:00:00.000',
#   'agency': 'DOB',
#   'agency_name': 'Department of Buildings',
#   'complaint_type': 'Elevator',
#   'descriptor': 'Elevator - Single Device On Property/No Alternate Service',
#   'incident_zip': '10038',
#   'incident_address': '25 PARK ROW',
#   'street_name': 'PARK ROW',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Buildings investigated this complaint and issued an Office of Administrative Trials and Hearings (OATH) summons.',
#   'resolution_action_updated_date': '2020-06-29T00:00:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000907504',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982193',
#   'y_coordinate_state_plane': '198532',
#   'open_data_channel_type': 'UNKNOWN',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7116009',
#   'longitude': '-74.0074198',
#   'location': {'latitude': '40.7116009',
#    'longitude': '-74.0074198',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46598396',
#   'created_date': '2020-06-23T13:42:00.000',
#   'closed_date': '2020-07-17T12:00:00.000',
#   'agency': 'DSNY',
#   'agency_name': 'A - Manhattan',
#   'complaint_type': 'Dirty Conditions',
#   'descriptor': 'E3A Dirty Area/Alleyway',
#   'location_type': 'Lot',
#   'incident_zip': '10038',
#   'incident_address': '21 ANN STREET',
#   'street_name': 'ANN STREET',
#   'cross_street_1': 'THEATER ALLEY',
#   'cross_street_2': 'NASSAU STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Sanitation has investigated the complaint and addressed the issue. If the problem persists, call 311 to enter a new complaint. If you are outside of New York City, please call (212) NEW-YORK (212-639-9675).',
#   'resolution_action_updated_date': '2020-07-17T12:00:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000900017',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982117',
#   'y_coordinate_state_plane': '198232',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7107775',
#   'longitude': '-74.0076938',
#   'location': {'latitude': '40.7107775',
#    'longitude': '-74.0076938',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46661236',
#   'created_date': '2020-06-27T13:51:07.000',
#   'closed_date': '2020-06-30T00:00:00.000',
#   'agency': 'DOB',
#   'agency_name': 'Department of Buildings',
#   'complaint_type': 'General Construction/Plumbing',
#   'descriptor': 'Cons - Contrary/Beyond Approved Plans/Permits',
#   'incident_zip': '10038',
#   'incident_address': '102 JOHN STREET',
#   'street_name': 'JOHN STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Buildings determined that the conditions described in this complaint were addressed under another service request number. Click on "Learn More" in the "Did You Know" section below for more information.',
#   'resolution_action_updated_date': '2020-06-30T00:00:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000690053',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982557',
#   'y_coordinate_state_plane': '197201',
#   'open_data_channel_type': 'UNKNOWN',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7079477',
#   'longitude': '-74.0061065',
#   'location': {'latitude': '40.7079477',
#    'longitude': '-74.0061065',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46677143',
#   'created_date': '2020-06-29T13:21:08.000',
#   'closed_date': '2020-06-29T13:21:08.000',
#   'agency': 'DOB',
#   'agency_name': 'Department of Buildings',
#   'complaint_type': 'General Construction/Plumbing',
#   'descriptor': 'Site Conditions Endangering Workers',
#   'incident_zip': '10038',
#   'incident_address': '102 JOHN STREET',
#   'street_name': 'JOHN STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Buildings investigated this complaint and determined that no further action was necessary.',
#   'resolution_action_updated_date': '2020-06-29T00:00:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000690053',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982557',
#   'y_coordinate_state_plane': '197201',
#   'open_data_channel_type': 'UNKNOWN',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7079477',
#   'longitude': '-74.0061065',
#   'location': {'latitude': '40.7079477',
#    'longitude': '-74.0061065',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '43663933',
#   'created_date': '2019-08-28T12:15:39.000',
#   'closed_date': '2019-09-13T12:03:21.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Bus Stop Shelter Complaint',
#   'descriptor': 'Broken Glass',
#   'location_type': 'Street',
#   'incident_zip': '10038',
#   'incident_address': '38 PARK ROW',
#   'street_name': 'PARK ROW',
#   'cross_street_1': 'BEEKMAN STREET',
#   'cross_street_2': 'BEND',
#   'intersection_street_1': 'BEEKMAN STREET',
#   'intersection_street_2': 'BEND',
#   'city': 'NEW YORK',
#   'landmark': 'PARK ROW',
#   'status': 'Closed',
#   'resolution_description': 'The contractor has reported that the requested work has been completed.',
#   'resolution_action_updated_date': '2019-09-13T12:03:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1001010001',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982404',
#   'y_coordinate_state_plane': '198608',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.71180963711092',
#   'longitude': '-74.00665868995252',
#   'location': {'latitude': '40.71180963711092',
#    'longitude': '-74.00665868995252',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '44050291',
#   'created_date': '2019-10-14T10:03:21.000',
#   'closed_date': '2019-10-14T12:00:20.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Panhandling',
#   'descriptor': 'N/A',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '10038',
#   'incident_address': '182 BROADWAY',
#   'street_name': 'BROADWAY',
#   'cross_street_1': 'CORTLANDT STREET',
#   'cross_street_2': 'JOHN STREET',
#   'intersection_street_1': 'CORTLANDT STREET',
#   'intersection_street_2': 'JOHN STREET',
#   'city': 'NEW YORK',
#   'landmark': 'BROADWAY',
#   'status': 'Closed',
#   'resolution_description': 'The Police Department responded to the complaint and took action to fix the condition.',
#   'resolution_action_updated_date': '2019-10-14T16:00:21.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000657502',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '981551',
#   'y_coordinate_state_plane': '197981',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7100884',
#   'longitude': '-74.0097353',
#   'location': {'latitude': '40.7100884',
#    'longitude': '-74.0097353',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '43319562',
#   'created_date': '2019-07-18T18:21:09.000',
#   'closed_date': '2019-09-23T11:43:28.000',
#   'agency': 'TLC',
#   'agency_name': 'Taxi and Limousine Commission',
#   'complaint_type': 'For Hire Vehicle Complaint',
#   'descriptor': 'Driver Complaint - Non Passenger',
#   'incident_zip': '10038',
#   'incident_address': '42 PARK ROW',
#   'street_name': 'PARK ROW',
#   'cross_street_1': 'BEEKMAN STREET',
#   'cross_street_2': 'BEND',
#   'intersection_street_1': 'BEEKMAN STREET',
#   'intersection_street_2': 'BEND',
#   'city': 'NEW YORK',
#   'landmark': 'PARK ROW',
#   'status': 'Closed',
#   'resolution_description': 'The Taxi and Limousine Commission was unable to identify the driver or car service company named in your complaint.',
#   'resolution_action_updated_date': '2020-02-04T15:17:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1001010002',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982515',
#   'y_coordinate_state_plane': '198644',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'taxi_pick_up_location': '42 PARK ROW, MANHATTAN (NEW YORK), NY, 10038',
#   'latitude': '40.711908471009096',
#   'longitude': '-74.00625831213233',
#   'location': {'latitude': '40.711908471009096',
#    'longitude': '-74.00625831213233',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '43379148',
#   'created_date': '2019-07-25T04:13:46.000',
#   'closed_date': '2019-07-25T10:22:54.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Street Sign - Dangling',
#   'descriptor': 'Other/Unknown',
#   'location_type': 'Street',
#   'incident_zip': '10038',
#   'incident_address': '59 MAIDEN LANE',
#   'street_name': 'MAIDEN LANE',
#   'cross_street_1': 'NASSAU STREET',
#   'cross_street_2': 'WILLIAM STREET',
#   'intersection_street_1': 'NASSAU STREET',
#   'intersection_street_2': 'WILLIAM STREET',
#   'city': 'NEW YORK',
#   'landmark': 'MAIDEN LANE',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Transportation inspected the condition you reported. You can find additional information in the "Notes to Customer" field.',
#   'resolution_action_updated_date': '2019-07-25T14:23:36.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000670001',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '981968',
#   'y_coordinate_state_plane': '197317',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.708266046703514',
#   'longitude': '-74.0082309440472',
#   'location': {'latitude': '40.708266046703514',
#    'longitude': '-74.0082309440472',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46778116',
#   'created_date': '2020-07-06T18:45:00.000',
#   'closed_date': '2020-07-06T23:50:00.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Traffic Signal Condition',
#   'descriptor': 'Controller',
#   'incident_zip': '10038',
#   'intersection_street_1': 'PEARL STREET',
#   'intersection_street_2': 'MADISON STREET',
#   'address_type': 'INTERSECTION',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'Service Request status for this request is available on the Department of Transportation?s website. Please click the ?Learn More? link below.',
#   'resolution_action_updated_date': '2020-07-06T23:50:00.000',
#   'community_board': '01 MANHATTAN',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '984008',
#   'y_coordinate_state_plane': '198567',
#   'open_data_channel_type': 'UNKNOWN',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7116973',
#   'longitude': '-74.0008729',
#   'location': {'latitude': '40.7116973',
#    'longitude': '-74.0008729',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '43462765',
#   'created_date': '2019-08-04T16:12:32.000',
#   'closed_date': '2019-08-08T10:40:11.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Street Sign - Damaged',
#   'descriptor': 'One Way',
#   'location_type': 'Street',
#   'incident_zip': '10038',
#   'incident_address': 'PEARL STREET',
#   'street_name': 'PEARL STREET',
#   'cross_street_1': 'FULTON STREET',
#   'cross_street_2': 'PEARL STREET',
#   'intersection_street_1': 'FULTON STREET',
#   'intersection_street_2': 'PEARL STREET',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Transportation has completed the request or corrected the condition.',
#   'resolution_action_updated_date': '2019-08-08T10:39:00.000',
#   'community_board': '01 MANHATTAN',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983050',
#   'y_coordinate_state_plane': '197156',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.707824352685094',
#   'longitude': '-74.00432825039411',
#   'location': {'latitude': '40.707824352685094',
#    'longitude': '-74.00432825039411',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '39947773',
#   'created_date': '2018-08-07T21:35:17.000',
#   'agency': 'DOHMH',
#   'agency_name': 'Department of Health and Mental Hygiene',
#   'complaint_type': 'Food Establishment',
#   'descriptor': 'Bare Hands in Contact w/ Food',
#   'location_type': 'Other (Explain Below)',
#   'incident_zip': '10038',
#   'incident_address': '11 FULTON STREET',
#   'street_name': 'FULTON STREET',
#   'cross_street_1': 'SOUTH STREET',
#   'cross_street_2': 'FRONT STREET',
#   'intersection_street_1': 'SOUTH STREET',
#   'intersection_street_2': 'FRONT STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'status': 'In Progress',
#   'due_date': '2018-09-13T21:35:17.000',
#   'resolution_description': 'The Department of Health and Mental Hygiene has received and processed your complaint. All restaurants and mobile food vendors are inspected annually. Restaurant inspection results can be found on WWW.NYC.GOV or a copy of the inspection can be requested from 311.',
#   'resolution_action_updated_date': '2018-08-09T15:29:12.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000960001',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983286',
#   'y_coordinate_state_plane': '196724',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7066386',
#   'longitude': '-74.003477',
#   'location': {'latitude': '40.7066386',
#    'longitude': '-74.003477',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '47840230',
#   'created_date': '2020-10-10T07:50:18.000',
#   'closed_date': '2020-10-13T13:14:34.000',
#   'agency': 'TLC',
#   'agency_name': 'Taxi and Limousine Commission',
#   'complaint_type': 'Lost Property',
#   'descriptor': 'Bag/Wallet',
#   'location_type': 'Taxi',
#   'incident_zip': '10038',
#   'incident_address': '199 WATER STREET',
#   'street_name': 'WATER STREET',
#   'cross_street_1': 'JOHN STREET',
#   'cross_street_2': 'FULTON STREET',
#   'intersection_street_1': 'JOHN STREET',
#   'intersection_street_2': 'FULTON STREET',
#   'city': 'NEW YORK',
#   'landmark': 'WATER STREET',
#   'status': 'Closed',
#   'resolution_description': 'See notes for information.',
#   'resolution_action_updated_date': '2020-10-13T17:14:36.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000747501',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983054',
#   'y_coordinate_state_plane': '196954',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'taxi_pick_up_location': '199 WATER STREET, MANHATTAN (NEW YORK), NY, 10038',
#   'latitude': '40.707269910970616',
#   'longitude': '-74.00431378701295',
#   'location': {'latitude': '40.707269910970616',
#    'longitude': '-74.00431378701295',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '43744376',
#   'created_date': '2019-09-07T16:40:02.000',
#   'closed_date': '2019-09-12T15:58:49.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Street Sign - Dangling',
#   'descriptor': 'No Parking, Standing, Stopping',
#   'location_type': 'Street',
#   'incident_zip': '10038',
#   'incident_address': '35 ANN STREET',
#   'street_name': 'ANN STREET',
#   'cross_street_1': 'NASSAU STREET',
#   'cross_street_2': 'WILLIAM STREET',
#   'intersection_street_1': 'NASSAU STREET',
#   'intersection_street_2': 'WILLIAM STREET',
#   'city': 'NEW YORK',
#   'landmark': 'ANN STREET',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Transportation has completed the request or corrected the condition.',
#   'resolution_action_updated_date': '2019-09-12T15:58:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000920023',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982260',
#   'y_coordinate_state_plane': '198126',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.710486630445786',
#   'longitude': '-74.00717796858433',
#   'location': {'latitude': '40.710486630445786',
#    'longitude': '-74.00717796858433',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46820853',
#   'created_date': '2020-07-11T23:22:00.000',
#   'closed_date': '2020-07-13T05:49:00.000',
#   'agency': 'DEP',
#   'agency_name': 'Department of Environmental Protection',
#   'complaint_type': 'Noise',
#   'descriptor': 'Noise, Ice Cream Truck (NR4)',
#   'incident_zip': '10038',
#   'incident_address': '251 WATER STREET',
#   'street_name': 'WATER STREET',
#   'cross_street_1': 'BEEKMAN ST',
#   'cross_street_2': 'PECK SLIP',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Environmental Protection determined that this complaint is a duplicate of a previously filed complaint. The original complaint is being addressed.',
#   'resolution_action_updated_date': '2020-07-13T05:49:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000970057',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983638',
#   'y_coordinate_state_plane': '197261',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7081126',
#   'longitude': '-74.0022074',
#   'location': {'latitude': '40.7081126',
#    'longitude': '-74.0022074',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46820864',
#   'created_date': '2020-07-11T06:46:00.000',
#   'closed_date': '2020-07-11T09:15:00.000',
#   'agency': 'DEP',
#   'agency_name': 'Department of Environmental Protection',
#   'complaint_type': 'Sewer',
#   'descriptor': 'Sewer Backup (Use Comments) (SA)',
#   'incident_zip': '10038',
#   'incident_address': '104 SOUTH STREET',
#   'street_name': 'SOUTH STREET',
#   'cross_street_1': 'BEEKMAN ST',
#   'cross_street_2': 'PECK SLIP',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Environmental Protection investigated this complaint and found there was no sewer back up in the city system at the time of the inspection.',
#   'resolution_action_updated_date': '2020-07-11T09:15:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000970010',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983644',
#   'y_coordinate_state_plane': '196782',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7067978',
#   'longitude': '-74.0021857',
#   'location': {'latitude': '40.7067978',
#    'longitude': '-74.0021857',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46825322',
#   'created_date': '2020-07-11T21:07:00.000',
#   'closed_date': '2020-07-13T19:00:00.000',
#   'agency': 'DEP',
#   'agency_name': 'Department of Environmental Protection',
#   'complaint_type': 'Noise',
#   'descriptor': 'Noise, Ice Cream Truck (NR4)',
#   'incident_zip': '10038',
#   'incident_address': '251 WATER STREET',
#   'street_name': 'WATER STREET',
#   'cross_street_1': 'BEEKMAN ST',
#   'cross_street_2': 'PECK SLIP',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Environmental Protection did not observe a violation of the New York City Air/Noise Code at the time of inspection and could not issue a notice of violation. If the problem still exists, please call 311 and file a new complaint. If you are outside of New York City, please call (212) NEW-YORK (212-639-9675).',
#   'resolution_action_updated_date': '2020-07-13T19:00:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000970057',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983638',
#   'y_coordinate_state_plane': '197261',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7081126',
#   'longitude': '-74.0022074',
#   'location': {'latitude': '40.7081126',
#    'longitude': '-74.0022074',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46512426',
#   'created_date': '2020-06-18T01:28:33.000',
#   'closed_date': '2020-06-18T03:40:48.000',
#   'agency': 'DHS',
#   'agency_name': 'Department of Homeless Services',
#   'complaint_type': 'Homeless Person Assistance',
#   'location_type': 'N/A',
#   'incident_zip': '10038',
#   'incident_address': '15 JOHN STREET',
#   'street_name': 'JOHN STREET',
#   'cross_street_1': 'BROADWAY',
#   'cross_street_2': 'NASSAU STREET',
#   'intersection_street_1': 'BROADWAY',
#   'intersection_street_2': 'NASSAU STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'landmark': 'JOHN STREET',
#   'status': 'Closed',
#   'resolution_description': 'The mobile outreach response team offered services to the individual, but the individual did not accept assistance.',
#   'resolution_action_updated_date': '2020-06-18T03:40:48.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000790014',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '981755',
#   'y_coordinate_state_plane': '197932',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.709954018494344',
#   'longitude': '-74.00899944147315',
#   'location': {'latitude': '40.709954018494344',
#    'longitude': '-74.00899944147315',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '40523665',
#   'created_date': '2018-10-11T10:05:34.000',
#   'closed_date': '2020-03-09T15:21:48.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Street Sign - Damaged',
#   'descriptor': 'No Parking, Standing, Stopping',
#   'location_type': 'Street',
#   'incident_zip': '10038',
#   'incident_address': '22 JOHN STREET',
#   'street_name': 'JOHN STREET',
#   'cross_street_1': 'BROADWAY',
#   'cross_street_2': 'NASSAU STREET',
#   'intersection_street_1': 'BROADWAY',
#   'intersection_street_2': 'NASSAU STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Transportation has completed the request or corrected the condition.',
#   'resolution_action_updated_date': '2020-03-09T19:21:50.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000650007',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '981805',
#   'y_coordinate_state_plane': '197877',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.70980307049871',
#   'longitude': '-74.00881907197302',
#   'location': {'latitude': '40.70980307049871',
#    'longitude': '-74.00881907197302',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '40546533',
#   'created_date': '2018-10-14T11:58:13.000',
#   'agency': 'DOHMH',
#   'agency_name': 'Department of Health and Mental Hygiene',
#   'complaint_type': 'Non-Residential Heat',
#   'descriptor': 'Inadequate or No Heat',
#   'location_type': 'Building (Non-Residential)',
#   'incident_zip': '10038',
#   'incident_address': '90 MAIDEN LANE',
#   'street_name': 'MAIDEN LANE',
#   'cross_street_1': 'GOLD STREET',
#   'cross_street_2': 'PEARL STREET',
#   'intersection_street_1': 'GOLD STREET',
#   'intersection_street_2': 'PEARL STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'status': 'In Progress',
#   'due_date': '2018-11-20T11:58:13.000',
#   'resolution_description': 'The Department of Health and Mental Hygiene has sent official written notification to the Owner/Landlord warning them of potential violations and instructing them to correct the situation. If the situation persists 21 days after your initial complaint, please make a new complaint.',
#   'resolution_action_updated_date': '2018-10-18T17:26:23.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000420036',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982265',
#   'y_coordinate_state_plane': '196852',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7069898',
#   'longitude': '-74.0071596',
#   'location': {'latitude': '40.7069898',
#    'longitude': '-74.0071596',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '40633402',
#   'created_date': '2018-10-23T11:44:26.000',
#   'agency': 'DOHMH',
#   'agency_name': 'Department of Health and Mental Hygiene',
#   'complaint_type': 'Unsanitary Animal Facility',
#   'descriptor': 'Animal Waste',
#   'location_type': 'Kennel/Animal Shelter',
#   'incident_zip': '10038',
#   'incident_address': '85 SOUTH STREET',
#   'street_name': 'SOUTH STREET',
#   'cross_street_1': 'FLETCHER STREET',
#   'cross_street_2': 'JOHN STREET',
#   'intersection_street_1': 'FLETCHER STREET',
#   'intersection_street_2': 'JOHN STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'status': 'In Progress',
#   'due_date': '2018-11-22T11:44:26.000',
#   'resolution_description': 'The Department of Health and Mental Hygiene will review the Service Request. Complaints of this type usually result in Agency contact or an inspection. Status will be available from 311 within 30 days of the Service Request submission date Please note the Service Request number for future reference.',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000720027',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983096',
#   'y_coordinate_state_plane': '196352',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7056175',
#   'longitude': '-74.0041622',
#   'location': {'latitude': '40.7056175',
#    'longitude': '-74.0041622',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '40944757',
#   'created_date': '2018-11-15T07:46:18.000',
#   'agency': 'DOHMH',
#   'agency_name': 'Department of Health and Mental Hygiene',
#   'complaint_type': 'Food Establishment',
#   'descriptor': 'Food Contains Foreign Object',
#   'location_type': 'Restaurant/Bar/Deli/Bakery',
#   'incident_zip': '10038',
#   'incident_address': '65 NASSAU STREET',
#   'street_name': 'NASSAU STREET',
#   'cross_street_1': 'MAIDEN LANE',
#   'cross_street_2': 'JOHN STREET',
#   'intersection_street_1': 'MAIDEN LANE',
#   'intersection_street_2': 'JOHN STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'status': 'In Progress',
#   'due_date': '2018-12-22T07:46:18.000',
#   'resolution_description': 'The Department of Health and Mental Hygiene has received and processed your complaint. All restaurants and mobile food vendors are inspected annually. Restaurant inspection results can be found on WWW.NYC.GOV or a copy of the inspection can be requested from 311.',
#   'resolution_action_updated_date': '2018-11-16T16:22:54.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000657501',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '981863',
#   'y_coordinate_state_plane': '197712',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7093502',
#   'longitude': '-74.0086098',
#   'location': {'latitude': '40.7093502',
#    'longitude': '-74.0086098',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '47409434',
#   'created_date': '2020-08-30T16:38:21.000',
#   'closed_date': '2020-09-23T00:00:00.000',
#   'agency': 'DOB',
#   'agency_name': 'Department of Buildings',
#   'complaint_type': 'Elevator',
#   'descriptor': 'Elevator - Multiple Devices On Property',
#   'incident_zip': '10038',
#   'incident_address': '15 ST JAMES PLACE',
#   'street_name': 'ST JAMES PLACE',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Buildings reviewed this complaint and referred it to the New York City Housing Authority for further action.',
#   'resolution_action_updated_date': '2020-09-23T00:00:00.000',
#   'community_board': '03 MANHATTAN',
#   'bbl': '1001110100',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '984277',
#   'y_coordinate_state_plane': '198521',
#   'open_data_channel_type': 'UNKNOWN',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.71157103533941',
#   'longitude': '-73.9999026088922',
#   'location': {'latitude': '40.71157103533941',
#    'longitude': '-73.9999026088922',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '41165617',
#   'created_date': '2018-12-11T02:29:30.000',
#   'closed_date': '2019-06-10T13:11:19.000',
#   'agency': 'TLC',
#   'agency_name': 'Taxi and Limousine Commission',
#   'complaint_type': 'Taxi Complaint',
#   'descriptor': 'Driver Complaint - Passenger',
#   'incident_zip': '10038',
#   'incident_address': '200 WATER STREET',
#   'street_name': 'WATER STREET',
#   'address_type': 'LATLONG',
#   'city': 'NEW YORK',
#   'status': 'Closed',
#   'due_date': '2019-01-19T11:04:16.000',
#   'resolution_description': 'A hearing was scheduled at the OATH/Taxi and Limousine Tribunal.',
#   'resolution_action_updated_date': '2019-06-10T17:11:19.000',
#   'community_board': '01 MANHATTAN',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982937',
#   'y_coordinate_state_plane': '197004',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'taxi_pick_up_location': '200 WATER STREET MANHATTAN',
#   'latitude': '40.7074098',
#   'longitude': '-74.0047358',
#   'location': {'latitude': '40.7074098',
#    'longitude': '-74.0047358',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '44964544',
#   'created_date': '2019-11-19T15:30:52.000',
#   'closed_date': '2020-01-07T19:07:12.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Sidewalk Condition',
#   'descriptor': 'Broken Sidewalk',
#   'location_type': 'Sidewalk',
#   'incident_zip': '10038',
#   'incident_address': '80 GOLD STREET',
#   'street_name': 'GOLD STREET',
#   'cross_street_1': 'BEEKMAN STREET',
#   'cross_street_2': 'SPRUCE STREET',
#   'intersection_street_1': 'BEEKMAN STREET',
#   'intersection_street_2': 'SPRUCE STREET',
#   'city': 'NEW YORK',
#   'landmark': 'GOLD STREET',
#   'status': 'Closed',
#   'resolution_description': 'The request submitted did not have sufficient information for the Department of Transportation to respond.',
#   'resolution_action_updated_date': '2020-01-08T00:07:15.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000940001',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983003',
#   'y_coordinate_state_plane': '197926',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.70993781382279',
#   'longitude': '-74.0044979161419',
#   'location': {'latitude': '40.70993781382279',
#    'longitude': '-74.0044979161419',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '44973382',
#   'created_date': '2019-11-19T20:11:22.000',
#   'closed_date': '2020-02-25T11:06:44.000',
#   'agency': 'DPR',
#   'agency_name': 'Department of Parks and Recreation',
#   'complaint_type': 'New Tree Request',
#   'descriptor': 'For One Address',
#   'location_type': 'Street',
#   'incident_zip': '10038',
#   'incident_address': '270 WATER STREET',
#   'street_name': 'WATER STREET',
#   'cross_street_1': 'PECK SLIP',
#   'cross_street_2': 'DOVER STREET',
#   'intersection_street_1': 'PECK SLIP',
#   'intersection_street_2': 'DOVER STREET',
#   'city': 'NEW YORK',
#   'landmark': 'WATER STREET',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Parks and Recreation has determined that the requested location cannot receive a new tree because of conflicts with surrounding infrastructure.',
#   'resolution_action_updated_date': '2020-02-25T16:06:48.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1001060005',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983904',
#   'y_coordinate_state_plane': '197441',
#   'open_data_channel_type': 'UNKNOWN',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.70860668486371',
#   'longitude': '-74.00124799350985',
#   'location': {'latitude': '40.70860668486371',
#    'longitude': '-74.00124799350985',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '45055227',
#   'created_date': '2019-12-01T10:08:24.000',
#   'closed_date': '2020-01-24T10:44:18.000',
#   'agency': 'TLC',
#   'agency_name': 'Taxi and Limousine Commission',
#   'complaint_type': 'Taxi Report',
#   'descriptor': 'Driver Report - Passenger',
#   'incident_zip': '10038',
#   'incident_address': 'JOHN STREET',
#   'street_name': 'JOHN STREET',
#   'cross_street_1': 'JOHN STREET',
#   'cross_street_2': 'WATER STREET',
#   'intersection_street_1': 'JOHN STREET',
#   'intersection_street_2': 'WATER STREET',
#   'status': 'Closed',
#   'resolution_description': 'Your report has been sent to the Taxi and Limousine Commission (TLC). You are not available to participate in a hearing so TLC cannot take any action against the driver or car service company. No further information will be available for your report.',
#   'resolution_action_updated_date': '2020-01-24T15:44:20.000',
#   'community_board': '01 MANHATTAN',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982863',
#   'y_coordinate_state_plane': '196802',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'taxi_pick_up_location': 'JOHN STREET AND WATER STREET, MANHATTAN, NY, 10038',
#   'latitude': '40.706852678991964',
#   'longitude': '-74.00500266315939',
#   'location': {'latitude': '40.706852678991964',
#    'longitude': '-74.00500266315939',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '45086908',
#   'created_date': '2019-12-05T19:39:02.000',
#   'closed_date': '2020-02-19T13:43:45.000',
#   'agency': 'TLC',
#   'agency_name': 'Taxi and Limousine Commission',
#   'complaint_type': 'Taxi Complaint',
#   'descriptor': 'Driver Complaint - Passenger',
#   'incident_zip': '10038',
#   'incident_address': '174 BROADWAY',
#   'street_name': 'BROADWAY',
#   'cross_street_1': 'CORTLANDT STREET',
#   'cross_street_2': 'JOHN STREET',
#   'intersection_street_1': 'CORTLANDT STREET',
#   'intersection_street_2': 'JOHN STREET',
#   'city': 'NEW YORK',
#   'landmark': 'BROADWAY',
#   'status': 'Closed',
#   'resolution_description': 'A representative from the Taxi and Limousine Commission (TLC) called and left a message for you and emailed you but has not been able to get in touch with you to confirm the details of your complaint. As a result, the TLC has closed your complaint. If you would like to have your complaint reopened, please call (212) 676-1046.',
#   'resolution_action_updated_date': '2020-02-19T18:43:47.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000650016',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '981502',
#   'y_coordinate_state_plane': '197905',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'taxi_pick_up_location': '174 BROADWAY, MANHATTAN (NEW YORK), NY, 10038',
#   'latitude': '40.709879834939315',
#   'longitude': '-74.00991199906008',
#   'location': {'latitude': '40.709879834939315',
#    'longitude': '-74.00991199906008',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '45091291',
#   'created_date': '2019-12-05T17:17:25.000',
#   'closed_date': '2020-01-24T11:17:08.000',
#   'agency': 'TLC',
#   'agency_name': 'Taxi and Limousine Commission',
#   'complaint_type': 'Taxi Complaint',
#   'descriptor': 'Driver Complaint - Passenger',
#   'incident_zip': '10038',
#   'incident_address': '123 NASSAU STREET',
#   'street_name': 'NASSAU STREET',
#   'cross_street_1': 'ANN STREET',
#   'cross_street_2': 'BEEKMAN STREET',
#   'intersection_street_1': 'ANN STREET',
#   'intersection_street_2': 'BEEKMAN STREET',
#   'city': 'NEW YORK',
#   'landmark': 'NASSAU STREET',
#   'status': 'Closed',
#   'resolution_description': 'The Taxi and Limousine Commission requires you to attend a hearing to process a complaint against a yellow cab driver. Your complaint has been closed.',
#   'resolution_action_updated_date': '2020-01-24T16:17:10.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000907503',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982347',
#   'y_coordinate_state_plane': '198299',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'taxi_pick_up_location': '123 NASSAU STREET, MANHATTAN (NEW YORK), NY, 10038',
#   'latitude': '40.71096149349733',
#   'longitude': '-74.00686420679716',
#   'location': {'latitude': '40.71096149349733',
#    'longitude': '-74.00686420679716',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '47063951',
#   'created_date': '2020-08-01T22:12:41.000',
#   'closed_date': '2020-08-02T13:40:27.000',
#   'agency': 'MAYORâ\x80\x99S OFFICE OF SPECIAL ENFORCEMENT',
#   'agency_name': 'Mayorâ\x80\x99s Office of Special Enforcement',
#   'complaint_type': 'NonCompliance with Phased Reopening',
#   'descriptor': 'Business not in compliance',
#   'location_type': 'Store/Commercial',
#   'incident_zip': '10038',
#   'incident_address': '100 JOHN STREET',
#   'street_name': 'JOHN STREET',
#   'cross_street_1': 'GOLD STREET',
#   'cross_street_2': 'CLIFF STREET',
#   'intersection_street_1': 'GOLD STREET',
#   'intersection_street_2': 'CLIFF STREET',
#   'city': 'NEW YORK',
#   'landmark': 'JOHN STREET',
#   'status': 'Closed',
#   'resolution_description': 'The Office of Special Enforcement investigated or referred to another agency for investigation and determined that it did not relate to a business.',
#   'resolution_action_updated_date': '2020-08-02T17:40:31.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000697502',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982541',
#   'y_coordinate_state_plane': '197214',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.70798346529741',
#   'longitude': '-74.0061641646523',
#   'location': {'latitude': '40.70798346529741',
#    'longitude': '-74.0061641646523',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '45918408',
#   'created_date': '2020-03-30T09:55:01.000',
#   'closed_date': '2020-03-30T15:03:01.000',
#   'agency': 'DHS',
#   'agency_name': 'Department of Homeless Services',
#   'complaint_type': 'Homeless Person Assistance',
#   'location_type': 'N/A',
#   'incident_zip': '10038',
#   'incident_address': '95 FULTON STREET',
#   'street_name': 'FULTON STREET',
#   'cross_street_1': 'GOLD STREET',
#   'cross_street_2': 'WILLIAM STREET',
#   'intersection_street_1': 'GOLD STREET',
#   'intersection_street_2': 'WILLIAM STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'landmark': 'FULTON STREET',
#   'status': 'Closed',
#   'resolution_description': 'The mobile outreach response team offered services to the individual, but the individual did not accept assistance.',
#   'resolution_action_updated_date': '2020-03-30T15:03:01.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000930001',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982546',
#   'y_coordinate_state_plane': '197738',
#   'open_data_channel_type': 'MOBILE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.70942172219195',
#   'longitude': '-74.00614626284509',
#   'location': {'latitude': '40.70942172219195',
#    'longitude': '-74.00614626284509',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46001818',
#   'created_date': '2020-04-14T12:51:30.000',
#   'closed_date': '2020-04-14T14:17:53.000',
#   'agency': 'DHS',
#   'agency_name': 'Department of Homeless Services',
#   'complaint_type': 'Homeless Person Assistance',
#   'location_type': 'N/A',
#   'incident_zip': '10038',
#   'incident_address': '95 FULTON STREET',
#   'street_name': 'FULTON STREET',
#   'cross_street_1': 'GOLD STREET',
#   'cross_street_2': 'WILLIAM STREET',
#   'intersection_street_1': 'GOLD STREET',
# ...
#   'park_borough': 'MANHATTAN'},
#  {'unique_key': '46991200',
#   'created_date': '2020-07-26T10:52:06.000',
#   'closed_date': '2020-07-29T12:11:35.000',
#   'agency': 'MAYORâ\x80\x99S OFFICE OF SPECIAL ENFORCEMENT',
#   'agency_name': 'Mayorâ\x80\x99s Office of Special Enforcement',
#   'complaint_type': 'NonCompliance with Phased Reopening',
#   'descriptor': 'Business not in compliance',
#   'location_type': 'Store/Commercial',
#   'incident_zip': '10038',
#   'incident_address': '55 FULTON STREET',
#   'street_name': 'FULTON STREET',
#   'cross_street_1': 'CLIFF STREET',
#   'cross_street_2': 'RYDERS ALLEY',
#   'intersection_street_1': 'CLIFF STREET',
#   'intersection_street_2': 'RYDERS ALLEY',
#   'city': 'NEW YORK',
#   'landmark': 'FULTON STREET',
#   'status': 'Closed',
#   'resolution_description': 'The Office of Special Enforcement investigated or referred to another agency for investigation and it was determined that the business is allowed to be open but was not in compliance with reopening guidelines, and a warning was issued.',
#   'resolution_action_updated_date': '2020-07-29T16:11:51.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000940001',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982906',
#   'y_coordinate_state_plane': '197383',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.70844739328294',
#   'longitude': '-74.00484768575112',
#   'location': {'latitude': '40.70844739328294',
#    'longitude': '-74.00484768575112',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '16843925',
#   'created_date': '2010-06-12T01:32:33.000',
#   'closed_date': '2010-07-06T02:12:27.000',
#   'agency': 'TLC',
#   'agency_name': 'Taxi and Limousine Commission',
#   'complaint_type': 'Taxi Complaint',
#   'descriptor': 'Driver Complaint',
#   'location_type': 'Street',
#   'incident_zip': '10038',
#   'incident_address': '99 JOHN STREET',
#   'street_name': 'JOHN STREET',
#   'cross_street_1': 'GOLD STREET',
#   'cross_street_2': 'CLIFF STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Closed',
#   'due_date': '2010-07-06T11:28:01.000',
#   'resolution_description': 'The complaint confirmation letter was not returned to the Taxi and Limousine Commission, therefore the complaint cannot be processed.',
#   'resolution_action_updated_date': '2010-07-06T02:12:27.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000767502',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982541',
#   'y_coordinate_state_plane': '197222',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'taxi_pick_up_location': 'Intersection',
#   'latitude': '40.7080054',
#   'longitude': '-74.0061642',
#   'location': {'latitude': '40.7080054',
#    'longitude': '-74.0061642',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '16844527',
#   'created_date': '2010-06-11T17:44:12.000',
#   'closed_date': '2010-06-11T18:03:06.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Noise - Vehicle',
#   'descriptor': 'Engine Idling',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '10038',
#   'incident_address': '15 CLIFF STREET',
#   'street_name': 'CLIFF STREET',
#   'cross_street_1': 'JOHN STREET',
#   'cross_street_2': 'FULTON STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'Precinct',
#   'status': 'Closed',
#   'due_date': '2010-06-12T01:44:12.000',
#   'resolution_description': 'The Police Department responded and upon arrival those responsible for the condition were gone.',
#   'resolution_action_updated_date': '2010-06-11T18:03:06.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000767501',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982743',
#   'y_coordinate_state_plane': '197274',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7081481',
#   'longitude': '-74.0054356',
#   'location': {'latitude': '40.7081481',
#    'longitude': '-74.0054356',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '47288503',
#   'created_date': '2020-08-18T14:56:58.000',
#   'closed_date': '2020-08-19T08:58:43.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Street Condition',
#   'descriptor': 'Cave-in',
#   'location_type': 'Street',
#   'incident_zip': '10038',
#   'incident_address': '1 POLICE PLAZA',
#   'street_name': 'POLICE PLAZA',
#   'cross_street_1': 'MADISON STREET',
#   'cross_street_2': 'PARK ROW',
#   'intersection_street_1': 'MADISON STREET',
#   'intersection_street_2': 'PARK ROW',
#   'city': 'NEW YORK',
#   'landmark': 'POLICE PLAZA',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Transportation inspected and has requested the Department of Environmental Protection address the issue. The condition will be re-inspected in 60 days.',
#   'resolution_action_updated_date': '2020-08-19T12:58:46.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1001190001',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '984002',
#   'y_coordinate_state_plane': '198801',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.712339565281404',
#   'longitude': '-74.00089456567466',
#   'location': {'latitude': '40.712339565281404',
#    'longitude': '-74.00089456567466',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '46992747',
#   'created_date': '2020-07-26T06:54:20.000',
#   'closed_date': '2020-07-26T07:08:26.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Posted Parking Sign Violation',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '10038',
#   'incident_address': '151 MAIDEN LANE',
#   'street_name': 'MAIDEN LANE',
#   'cross_street_1': 'FRONT STREET',
#   'cross_street_2': 'SOUTH STREET',
#   'intersection_street_1': 'FRONT STREET',
#   'intersection_street_2': 'SOUTH STREET',
#   'city': 'NEW YORK',
#   'landmark': 'MAIDEN LANE',
#   'status': 'Closed',
#   'resolution_description': 'The Police Department responded to the complaint and determined that police action was not necessary.',
#   'resolution_action_updated_date': '2020-07-26T11:08:29.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000720007',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982753',
#   'y_coordinate_state_plane': '196387',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.705713583966244',
#   'longitude': '-74.00539932139957',
#   'location': {'latitude': '40.705713583966244',
#    'longitude': '-74.00539932139957',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '16856997',
#   'created_date': '2010-06-14T14:40:13.000',
#   'agency': 'DOHMH',
#   'agency_name': 'Department of Health and Mental Hygiene',
#   'complaint_type': 'Food Establishment',
#   'descriptor': 'Food Contains Foreign Object',
#   'location_type': 'Restaurant/Bar/Deli/Bakery',
#   'incident_zip': '10038',
#   'incident_address': '65 NASSAU STREET',
#   'street_name': 'NASSAU STREET',
#   'cross_street_1': 'MAIDEN LANE',
#   'cross_street_2': 'JOHN STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'facility_type': 'N/A',
#   'status': 'Pending',
#   'due_date': '2010-07-21T14:40:13.000',
#   'resolution_description': 'The Department of Health and Mental Hygiene has received and processed your complaint. All restaurants and mobile food vendors are inspected annually. Restaurant inspection results can be found on WWW.NYC.GOV or a copy of the inspection can be requested from 311.',
#   'resolution_action_updated_date': '2010-06-15T11:30:55.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000657501',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '981863',
#   'y_coordinate_state_plane': '197712',
#   'open_data_channel_type': 'UNKNOWN',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7093502',
#   'longitude': '-74.0086098',
#   'location': {'latitude': '40.7093502',
#    'longitude': '-74.0086098',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '44987386',
#   'created_date': '2019-11-21T00:00:00.000',
#   'closed_date': '2019-11-21T00:00:01.000',
#   'agency': 'DOHMH',
#   'agency_name': 'Department of Health and Mental Hygiene',
#   'complaint_type': 'Food Poisoning',
#   'descriptor': '1 or 2',
#   'location_type': 'Restaurant',
#   'incident_zip': '10038',
#   'incident_address': '200 BROADWAY',
#   'street_name': 'BROADWAY',
#   'cross_street_1': 'DEY STREET',
#   'cross_street_2': 'FULTON STREET',
#   'intersection_street_1': 'DEY STREET',
#   'intersection_street_2': 'FULTON STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'landmark': 'BROADWAY',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Health and Mental Hygiene has determined that the reported incident is isolated.The establishment will be inspected according to its normal schedule for sanitary inspections.',
#   'resolution_action_updated_date': '2019-12-03T15:50:38.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000790015',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '981657',
#   'y_coordinate_state_plane': '198143',
#   'open_data_channel_type': 'PHONE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7105331',
#   'longitude': '-74.009353',
#   'location': {'latitude': '40.7105331',
#    'longitude': '-74.009353',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '44984874',
#   'created_date': '2019-11-21T07:28:48.000',
#   'closed_date': '2019-11-21T09:34:47.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Panhandling',
#   'descriptor': 'N/A',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '10038',
#   'incident_address': '160 BROADWAY',
#   'street_name': 'BROADWAY',
#   'cross_street_1': 'LIBERTY STREET',
#   'cross_street_2': 'CORTLANDT STREET',
#   'intersection_street_1': 'LIBERTY STREET',
#   'intersection_street_2': 'CORTLANDT STREET',
#   'city': 'NEW YORK',
#   'landmark': 'BROADWAY',
#   'status': 'Closed',
#   'resolution_description': 'The Police Department responded to the complaint and determined that police action was not necessary.',
#   'resolution_action_updated_date': '2019-11-21T14:34:49.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000640015',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '981411',
#   'y_coordinate_state_plane': '197764',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.7094928',
#   'longitude': '-74.0102402',
#   'location': {'latitude': '40.7094928',
#    'longitude': '-74.0102402',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '47172492',
#   'created_date': '2020-08-08T16:49:39.000',
#   'closed_date': '2020-08-13T00:00:00.000',
#   'agency': 'DOB',
#   'agency_name': 'Department of Buildings',
#   'complaint_type': 'Elevator',
#   'descriptor': 'Elevator - Single Device On Property/No Alternate Service',
#   'incident_zip': '10038',
#   'incident_address': '47 ANN STREET',
#   'street_name': 'ANN STREET',
#   'address_type': 'ADDRESS',
#   'city': 'NEW YORK',
#   'status': 'Closed',
#   'resolution_description': 'The Department of Buildings investigated this complaint and determined that no further action was necessary.',
#   'resolution_action_updated_date': '2020-08-13T00:00:00.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000920017',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982343',
#   'y_coordinate_state_plane': '198070',
#   'open_data_channel_type': 'UNKNOWN',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.71033294201819',
#   'longitude': '-74.00687857011478',
#   'location': {'latitude': '40.71033294201819',
#    'longitude': '-74.00687857011478',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '47021795',
#   'created_date': '2020-07-29T11:02:32.000',
#   'closed_date': '2020-07-29T11:14:13.000',
#   'agency': 'NYPD',
#   'agency_name': 'New York City Police Department',
#   'complaint_type': 'Illegal Parking',
#   'descriptor': 'Posted Parking Sign Violation',
#   'location_type': 'Street/Sidewalk',
#   'incident_zip': '10038',
#   'incident_address': '213 FRONT STREET',
#   'street_name': 'FRONT STREET',
#   'cross_street_1': 'BEEKMAN STREET',
#   'cross_street_2': 'PECK SLIP',
#   'intersection_street_1': 'BEEKMAN STREET',
#   'intersection_street_2': 'PECK SLIP',
#   'city': 'NEW YORK',
#   'landmark': 'FRONT STREET',
#   'status': 'Closed',
#   'resolution_description': 'The Police Department responded to the complaint and determined that police action was not necessary.',
#   'resolution_action_updated_date': '2020-07-29T15:14:21.000',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000970018',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '983551',
#   'y_coordinate_state_plane': '196972',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.707319369938226',
#   'longitude': '-74.0025211867546',
#   'location': {'latitude': '40.707319369938226',
#    'longitude': '-74.0025211867546',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '47023516',
#   'created_date': '2020-07-29T14:23:00.000',
#   'closed_date': '2020-07-29T14:23:00.000',
#   'agency': 'DOT',
#   'agency_name': 'Department of Transportation',
#   'complaint_type': 'Street Light Condition',
#   'descriptor': 'Fixture/Luminaire Door Open',
#   'incident_zip': '10038',
#   'intersection_street_1': 'NASSAU STREET',
#   'intersection_street_2': 'ANN STREET',
#   'address_type': 'INTERSECTION',
#   'city': 'NEW YORK',
#   'status': 'Closed',
#   'resolution_description': 'Service Request status for this request is available on the Department of Transportationâ\x80\x99s website. Please click the â\x80\x9cLearn Moreâ\x80\x9d link below.',
#   'resolution_action_updated_date': '2020-07-29T00:35:00.000',
#   'community_board': '01 MANHATTAN',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982205',
#   'y_coordinate_state_plane': '198160',
#   'open_data_channel_type': 'UNKNOWN',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.71057993983175',
#   'longitude': '-74.00737636497693',
#   'location': {'latitude': '40.71057993983175',
#    'longitude': '-74.00737636497693',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}},
#  {'unique_key': '47301941',
#   'created_date': '2020-08-20T22:45:40.000',
#   'agency': 'DOHMH',
#   'agency_name': 'Department of Health and Mental Hygiene',
#   'complaint_type': 'Day Care',
#   'descriptor': 'Day Care Facility',
#   'location_type': 'Commercial Building',
#   'incident_zip': '10038',
#   'incident_address': '101 JOHN STREET',
#   'street_name': 'JOHN STREET',
#   'cross_street_1': 'GOLD STREET',
#   'cross_street_2': 'CLIFF STREET',
#   'intersection_street_1': 'GOLD STREET',
#   'intersection_street_2': 'CLIFF STREET',
#   'city': 'NEW YORK',
#   'landmark': 'JOHN STREET',
#   'status': 'In Progress',
#   'community_board': '01 MANHATTAN',
#   'bbl': '1000767502',
#   'borough': 'MANHATTAN',
#   'x_coordinate_state_plane': '982561',
#   'y_coordinate_state_plane': '197205',
#   'open_data_channel_type': 'ONLINE',
#   'park_facility_name': 'Unspecified',
#   'park_borough': 'MANHATTAN',
#   'latitude': '40.707958766266344',
#   'longitude': '-74.00609202471617',
#   'location': {'latitude': '40.707958766266344',
#    'longitude': '-74.00609202471617',
#    'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}}]
